# %% [markdown]
# <a href="https://colab.research.google.com/github/SheYuting/char_transformer/blob/main/transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Enable autoreload of local Python modules (e.g., models)
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import numpy as np
import jax
import jax.numpy as jnp
import optax
import time

# local imports
import models as models
import generation as generation

# %%
# initialize the jax random key
key = jax.random.key(0)

# %% [markdown]
# # Load data

# %%
# load the ./data/text8_train.txt and ./data/text8_test.txt files
with open("./text8_train.txt", "r") as f:
    train_text = f.read()
with open("./text8_test.txt", "r") as f:
    test_text = f.read()

# print the length of the training text and test text
print(f"Length of training text: {len(train_text):_} characters")
print(f"Length of test text: {len(test_text):_} characters")
# Out:
# Length of training text: 90_000_000 characters
# Length of test text: 5_000_000 characters

# %%
# Build vocabulary (lowercase + space + a few punctuations)
char_set = list("abcdefghijklmnopqrstuvwxyz ")
char_to_int = {ch:i for i,ch in enumerate(char_set)}
int_to_char = {i:ch for ch,i in char_to_int.items()}

def encode(s):
    """Encode string to array of integers"""
    ids = [char_to_int[c] for c in s]
    return np.array(ids, dtype=np.uint8)  # use np.uint8 to save space

# %%
# encode the text
train_text_int = encode(train_text)
test_text_int = encode(test_text)

# %%
# sanity check: display a few random characters from the training text
T = 128
for _ in range(5):
    # choose random position in text
    N = np.random.randint(low=0, high=len(train_text)-T)
    print(train_text[N:N+T])
    print()
# Out:
# entially all of the world s writing systems see unicode and bob bemer codes to detect or correct errors e g in storage or transm
#
# on although any relationship thereto is based on modern borrowing of discrete facets derived from recent historical and archaelo
#
# vance guerrilla warfare in the chinese civil war both before and after the sino japanese war there was continuous fighting betwe
#
# ally a large part of the territory of the present day azerbaijan republic has been called arran named after arran a legendary fo
#
#  be found in jersey only fragmentary wall paintings remain from the rich mediaeval artistic heritage after the wholesale iconocl

# %% [markdown]
# # Create a basic Transformer model

# %%
def create_train_state(rng, vocab_size=27, d_model=64, n_layers=6, n_heads=8, max_len=128):
    # create a basic Transformer model
    model = models.DecoderOnlyTransformer(vocab_size, d_model, n_layers, n_heads, max_len)
    # create a dummy input for initialization
    dummy = jnp.zeros((1, min(16, max_len)), dtype=jnp.int32)
    # pass the dummy input to the model to initialize the parameters
    params = model.init({"params": rng}, dummy)["params"]
    return model, params

# %%
# vocab size
vocab_size= len(char_set)

# internal model dimensions
d_model=256

# number of attention heads
n_heads=8

# number of Transformer layers
n_layers=2

# maximum sequence length
max_len=128

model, params = create_train_state(key, vocab_size, d_model, n_layers, n_heads, max_len)

# %%
# compute the number of parameters
def count_params(params):
    return sum(x.size for x in jax.tree_util.tree_leaves(params))
print(f"Number of parameters: {count_params(params):_}")
# Out:
# Number of parameters: 1_624_576

# %%
# sanity check: create a batch of data & run a forward pass
B, T = 4, 32
batch = jax.random.randint(
    key=key,
    shape=(B, T), minval=0, maxval=len(char_set))
logits = model.apply({"params": params}, batch)

print("batch shape:", batch.shape)  # (B, T)
print("logits shape:", logits.shape)  # (B, T, vocab_size)
# Out:
# batch shape: (4, 32)
# logits shape: (4, 32, 27)

# %% [markdown]
# # Loss function

# %%
@jax.jit
def loss_and_metrics(logits, targets, epsilon_ls: float = 0.1):
    """Compute cross-entropy loss (with label smoothing) and accuracy.

    Args:
      logits: (B, T, V) float array of unnormalized scores.
      targets: (B, T) int array with ground-truth class ids.
      epsilon_ls: label smoothing factor, e.g. 0.1.

    Returns:
      loss: scalar average cross-entropy over all positions.
      metrics: dict with keys "loss", "acc", "acc_last".
    """
    B, T, V = logits.shape

    # ---- label smoothing ----
    # flatten
    flat_logits = logits.reshape(-1, V)       # (B*T, V)
    flat_targets = targets.reshape(-1)        # (B*T,)

    # one-hot targets
    one_hot = jax.nn.one_hot(flat_targets, V)  # (B*T, V)

    # smoothed labels:
    #   (1 - eps) on true class, eps / V on all classes (including true one)
    smoothed = one_hot * (1.0 - epsilon_ls) + epsilon_ls / V

    # cross-entropy with soft target distribution
    # optax.softmax_cross_entropy expects probs as labels
    per_pos = optax.softmax_cross_entropy(flat_logits, smoothed)  # (B*T,)
    loss = per_pos.mean()

    # ---- accuracy (仍然用真实标签，不做平滑) ----
    preds = jnp.argmax(logits, axis=-1)  # (B, T)
    is_match = preds == targets
    is_match_f = is_match.astype(jnp.float32)

    acc_all = is_match_f.mean()
    acc_last = is_match_f[:, -1].mean()

    return loss, {"loss": loss, "acc": acc_all, "acc_last": acc_last}

# %% [markdown]
# # Optimization step:

# %%
def transformer_lr_schedule(d_model, warmup_steps=4000):
    """Noam learning rate schedule from 'Attention Is All You Need'.

    lrate = d_model^{-0.5} * min(step^{-0.5}, step * warmup^{-1.5})
    """
    def schedule(step):
        # step 从 0 开始，这里确保不会除以 0
        step = jnp.maximum(step, 1)

        inv_sqrt_step = step ** -0.5
        scaled_step = step * (warmup_steps ** -1.5)

        return (d_model ** -0.5) * jnp.minimum(inv_sqrt_step, scaled_step)

    return schedule

# %%
def train_step(params, opt_state, x, y, tx, rng):
    """Single optimization step using optax optimizer.

    Args:
      params: pytree of model parameters.
      opt_state: optax optimizer state.
      x, y: (B, T) int32.
      tx: optax optimizer (static).
      rng: jax.random.PRNGKey for dropout.

    Returns:
      new_params, new_opt_state, metrics, new_rng
    """
    # 为本次step生成一个专门给dropout用的子key
    rng, dropout_rng = jax.random.split(rng)

    def loss_fn(params):
        logits = model.apply(
            {"params": params},
            x,
            deterministic=False,                  # 训练时启用dropout
            rngs={"dropout": dropout_rng},        # 关键：给Dropout提供rng
        )
        loss, metrics = loss_and_metrics(logits, y)
        return loss, metrics

    (loss, metrics), grads = jax.value_and_grad(loss_fn, has_aux=True)(params)
    updates, new_opt_state = tx.update(grads, opt_state, params)
    new_params = optax.apply_updates(params, updates)

    # 把更新后的rng一并返回，供下一步使用
    return new_params, new_opt_state, metrics, rng

# 仍然只把 tx 作为 static arg
train_step = jax.jit(train_step, static_argnames=("tx",))

# %% [markdown]
# # Batch creation:

# %%
# create a batch from the training data
def get_batch(text_int, B, T):
    """Create a random batch of data from text_int.

    Args:
      text_int: 1D array of token ids.
      B: batch size (number of sequences).
      T: sequence length (number of tokens per sequence).

    Returns:
      x: (B, T) int array input tokens.
      y: (B, T) int array target tokens.
    """
    # choose random starting indices for each sequence in the batch
    ix = np.random.randint(0, len(text_int) - T, size=B)
    # inputs are text from i to i+T
    x = np.stack([text_int[i:i+T] for i in ix])
    # targets are text from i+1 to i+T+1
    y = np.stack([text_int[i+1:i+T+1] for i in ix])
    return jnp.array(x, dtype=jnp.int32), jnp.array(y, dtype=jnp.int32)

# %% [markdown]
# # Optimizer creation:

# %%
warmup_steps = 4000

# Noam learning rate schedule
learning_rate_schedule = transformer_lr_schedule(d_model=d_model,
                                                 warmup_steps=warmup_steps)

# Adam with Transformer-paper hyperparameters
tx = optax.adam(
    learning_rate=learning_rate_schedule,  # 注意这里传的是函数，不是常数
    b1=0.9,
    b2=0.98,
    eps=1e-9,
)

# Initialize optimizer state for current params
opt_state = tx.init(params)
print(f"Initialized optimizer: Adam with Noam schedule, "
      f"d_model={d_model}, warmup_steps={warmup_steps}")
# Out:
# Initialized optimizer: Adam with Noam schedule, d_model=256, warmup_steps=4000

# %%
niter = 100_000
B, T = 128, 32
loss_history = []
time_history = []
time_test_history = []
loss_test_history = []
time_start = time.time()

for it in range(niter):
    batch = get_batch(train_text_int, B, T)
    input, target = batch[0], batch[1]

    # 这里把 key 传给 train_step，并接收更新后的 new_key
    params, opt_state, metrics, key = train_step(
        params, opt_state, input, target, tx, key
    )

    acc = metrics['acc']
    acc_last = metrics['acc_last']
    loss = metrics['loss']

    loss_history.append(loss)
    time_history.append(time.time() - time_start)

    if it % (niter // 50) == 0 or it == niter - 1:
        time_since_start = time.time() - time_start
        B_test, T_test = 1024, 32
        test_batch = get_batch(test_text_int, B_test, T_test)
        test_input, test_target = test_batch[0], test_batch[1]

        # 测试/验证时 deterministic=True，不需要 dropout rng
        test_logits = model.apply(
            {"params": params},
            test_input,
            deterministic=True,
        )
        test_loss, test_metrics = loss_and_metrics(test_logits, test_target)
        test_acc = test_metrics['acc']
        test_acc_last = test_metrics['acc_last']

        loss_test_history.append(test_loss)
        time_test_history.append(time_since_start)
        print(f"iteration {it:_}  time: {time_since_start:.1f} seconds")
        print(f"\t \t loss(train :: test): {loss:.4f} :: {test_loss:.4f}")
        print(f"\t \t accuracy (train :: test): {100*acc:.1f}% :: {100*test_acc:.1f}%")
        print(f"\t \t accuracy (last character) (train :: test): "
              f"{100*acc_last:.1f}% :: {100*test_acc_last:.1f}%")
        print()
# Out:
# iteration 0  time: 6.6 seconds
# 	 	 loss(train :: test): 1.9083 :: 1.9619
# 	 	 accuracy (train :: test): 58.0% :: 57.7%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 57.3%
#
# iteration 2_000  time: 47.3 seconds
# 	 	 loss(train :: test): 1.7791 :: 1.7410
# 	 	 accuracy (train :: test): 56.4% :: 58.0%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 60.8%
#
# iteration 4_000  time: 85.7 seconds
# 	 	 loss(train :: test): 1.7828 :: 1.7490
# 	 	 accuracy (train :: test): 55.9% :: 57.5%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 58.4%
#
# iteration 6_000  time: 125.5 seconds
# 	 	 loss(train :: test): 1.7286 :: 1.7504
# 	 	 accuracy (train :: test): 57.8% :: 57.5%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 61.3%
#
# iteration 8_000  time: 164.6 seconds
# 	 	 loss(train :: test): 1.7650 :: 1.7487
# 	 	 accuracy (train :: test): 57.3% :: 57.3%
# 	 	 accuracy (last character) (train :: test): 64.1% :: 58.6%
#
# iteration 10_000  time: 203.7 seconds
# 	 	 loss(train :: test): 1.7969 :: 1.7396
# 	 	 accuracy (train :: test): 56.0% :: 58.0%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 60.8%
#
# iteration 12_000  time: 243.0 seconds
# 	 	 loss(train :: test): 1.7680 :: 1.7435
# 	 	 accuracy (train :: test): 57.1% :: 57.7%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 61.5%
#
# iteration 14_000  time: 282.6 seconds
# 	 	 loss(train :: test): 1.7904 :: 1.7492
# 	 	 accuracy (train :: test): 55.6% :: 57.5%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 59.2%
#
# iteration 16_000  time: 321.9 seconds
# 	 	 loss(train :: test): 1.7526 :: 1.7230
# 	 	 accuracy (train :: test): 56.5% :: 58.2%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 57.7%
#
# iteration 18_000  time: 361.0 seconds
# 	 	 loss(train :: test): 1.7576 :: 1.7481
# 	 	 accuracy (train :: test): 57.1% :: 57.5%
# 	 	 accuracy (last character) (train :: test): 53.1% :: 58.6%
#
# iteration 20_000  time: 400.5 seconds
# 	 	 loss(train :: test): 1.7522 :: 1.7281
# 	 	 accuracy (train :: test): 57.8% :: 58.4%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 62.5%
#
# iteration 22_000  time: 439.7 seconds
# 	 	 loss(train :: test): 1.8050 :: 1.7362
# 	 	 accuracy (train :: test): 55.6% :: 57.6%
# 	 	 accuracy (last character) (train :: test): 54.7% :: 59.6%
#
# iteration 24_000  time: 478.8 seconds
# 	 	 loss(train :: test): 1.7921 :: 1.7312
# 	 	 accuracy (train :: test): 55.9% :: 57.9%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 60.7%
#
# iteration 26_000  time: 518.0 seconds
# 	 	 loss(train :: test): 1.7982 :: 1.7200
# 	 	 accuracy (train :: test): 56.0% :: 58.3%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 59.8%
#
# iteration 28_000  time: 557.3 seconds
# 	 	 loss(train :: test): 1.7776 :: 1.7402
# 	 	 accuracy (train :: test): 56.7% :: 57.9%
# 	 	 accuracy (last character) (train :: test): 66.4% :: 61.1%
#
# iteration 30_000  time: 596.5 seconds
# 	 	 loss(train :: test): 1.7611 :: 1.7246
# 	 	 accuracy (train :: test): 56.4% :: 58.2%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 58.8%
#
# iteration 32_000  time: 635.8 seconds
# 	 	 loss(train :: test): 1.7429 :: 1.7358
# 	 	 accuracy (train :: test): 57.4% :: 57.9%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 60.0%
#
# iteration 34_000  time: 675.0 seconds
# 	 	 loss(train :: test): 1.8075 :: 1.7419
# 	 	 accuracy (train :: test): 55.1% :: 57.7%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 61.5%
#
# iteration 36_000  time: 714.2 seconds
# 	 	 loss(train :: test): 1.7509 :: 1.7319
# 	 	 accuracy (train :: test): 57.5% :: 58.1%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 60.4%
#
# iteration 38_000  time: 753.6 seconds
# 	 	 loss(train :: test): 1.7290 :: 1.7259
# 	 	 accuracy (train :: test): 57.8% :: 58.3%
# 	 	 accuracy (last character) (train :: test): 52.3% :: 61.0%
#
# iteration 40_000  time: 793.0 seconds
# 	 	 loss(train :: test): 1.7540 :: 1.7254
# 	 	 accuracy (train :: test): 57.2% :: 58.5%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 60.0%
#
# iteration 42_000  time: 832.3 seconds
# 	 	 loss(train :: test): 1.7450 :: 1.7351
# 	 	 accuracy (train :: test): 57.4% :: 58.0%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 62.0%
#
# iteration 44_000  time: 871.7 seconds
# 	 	 loss(train :: test): 1.7378 :: 1.7136
# 	 	 accuracy (train :: test): 57.3% :: 58.8%
# 	 	 accuracy (last character) (train :: test): 52.3% :: 60.8%
#
# iteration 46_000  time: 910.9 seconds
# 	 	 loss(train :: test): 1.7793 :: 1.7288
# 	 	 accuracy (train :: test): 56.4% :: 58.0%
# 	 	 accuracy (last character) (train :: test): 53.9% :: 60.0%
#
# iteration 48_000  time: 950.1 seconds
# 	 	 loss(train :: test): 1.7070 :: 1.7265
# 	 	 accuracy (train :: test): 59.6% :: 58.2%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 58.8%
#
# iteration 50_000  time: 989.3 seconds
# 	 	 loss(train :: test): 1.7565 :: 1.7299
# 	 	 accuracy (train :: test): 57.4% :: 58.0%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 59.7%
#
# iteration 52_000  time: 1028.5 seconds
# 	 	 loss(train :: test): 1.6933 :: 1.7254
# 	 	 accuracy (train :: test): 58.8% :: 58.2%
# 	 	 accuracy (last character) (train :: test): 69.5% :: 58.9%
#
# iteration 54_000  time: 1067.7 seconds
# 	 	 loss(train :: test): 1.7355 :: 1.7389
# 	 	 accuracy (train :: test): 56.9% :: 57.6%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 60.9%
#
# iteration 56_000  time: 1106.8 seconds
# 	 	 loss(train :: test): 1.7466 :: 1.7222
# 	 	 accuracy (train :: test): 56.9% :: 58.6%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 60.6%
#
# iteration 58_000  time: 1146.1 seconds
# 	 	 loss(train :: test): 1.7410 :: 1.7253
# 	 	 accuracy (train :: test): 58.5% :: 58.2%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 60.8%
#
# iteration 60_000  time: 1185.3 seconds
# 	 	 loss(train :: test): 1.7585 :: 1.7014
# 	 	 accuracy (train :: test): 56.2% :: 59.0%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 61.7%
#
# iteration 62_000  time: 1224.5 seconds
# 	 	 loss(train :: test): 1.7928 :: 1.7227
# 	 	 accuracy (train :: test): 55.1% :: 58.3%
# 	 	 accuracy (last character) (train :: test): 54.7% :: 61.0%
#
# iteration 64_000  time: 1263.9 seconds
# 	 	 loss(train :: test): 1.7209 :: 1.7178
# 	 	 accuracy (train :: test): 58.4% :: 58.5%
# 	 	 accuracy (last character) (train :: test): 63.3% :: 62.3%
#
# iteration 66_000  time: 1303.2 seconds
# 	 	 loss(train :: test): 1.7621 :: 1.7082
# 	 	 accuracy (train :: test): 56.6% :: 58.7%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 62.4%
#
# iteration 68_000  time: 1342.7 seconds
# 	 	 loss(train :: test): 1.7783 :: 1.7246
# 	 	 accuracy (train :: test): 56.2% :: 58.0%
# 	 	 accuracy (last character) (train :: test): 53.9% :: 60.2%
#
# iteration 70_000  time: 1381.9 seconds
# 	 	 loss(train :: test): 1.7274 :: 1.7275
# 	 	 accuracy (train :: test): 57.5% :: 58.3%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 60.6%
#
# iteration 72_000  time: 1421.2 seconds
# 	 	 loss(train :: test): 1.7110 :: 1.7265
# 	 	 accuracy (train :: test): 57.8% :: 58.4%
# 	 	 accuracy (last character) (train :: test): 68.0% :: 63.9%
#
# iteration 74_000  time: 1460.4 seconds
# 	 	 loss(train :: test): 1.6996 :: 1.7266
# 	 	 accuracy (train :: test): 60.1% :: 58.7%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 60.3%
#
# iteration 76_000  time: 1499.6 seconds
# 	 	 loss(train :: test): 1.7334 :: 1.7070
# 	 	 accuracy (train :: test): 58.6% :: 59.2%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 60.7%
#
# iteration 78_000  time: 1538.8 seconds
# 	 	 loss(train :: test): 1.7435 :: 1.7298
# 	 	 accuracy (train :: test): 57.5% :: 57.8%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 63.8%
#
# iteration 80_000  time: 1578.0 seconds
# 	 	 loss(train :: test): 1.7714 :: 1.7205
# 	 	 accuracy (train :: test): 56.5% :: 58.5%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 64.3%
#
# iteration 82_000  time: 1617.2 seconds
# 	 	 loss(train :: test): 1.7457 :: 1.7134
# 	 	 accuracy (train :: test): 58.1% :: 58.5%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 60.4%
#
# iteration 84_000  time: 1656.3 seconds
# 	 	 loss(train :: test): 1.7406 :: 1.7190
# 	 	 accuracy (train :: test): 57.3% :: 58.5%
# 	 	 accuracy (last character) (train :: test): 50.8% :: 60.1%
#
# iteration 86_000  time: 1695.5 seconds
# 	 	 loss(train :: test): 1.7815 :: 1.7143
# 	 	 accuracy (train :: test): 56.1% :: 58.6%
# 	 	 accuracy (last character) (train :: test): 63.3% :: 58.3%
#
# iteration 88_000  time: 1734.7 seconds
# 	 	 loss(train :: test): 1.7453 :: 1.6969
# 	 	 accuracy (train :: test): 57.3% :: 59.1%
# 	 	 accuracy (last character) (train :: test): 53.1% :: 62.3%
#
# iteration 90_000  time: 1774.2 seconds
# 	 	 loss(train :: test): 1.7325 :: 1.7157
# 	 	 accuracy (train :: test): 57.7% :: 58.6%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 58.2%
#
# iteration 92_000  time: 1813.5 seconds
# 	 	 loss(train :: test): 1.7599 :: 1.7055
# 	 	 accuracy (train :: test): 57.4% :: 58.8%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 62.7%
#
# iteration 94_000  time: 1853.0 seconds
# 	 	 loss(train :: test): 1.7879 :: 1.7061
# 	 	 accuracy (train :: test): 56.1% :: 59.1%
# 	 	 accuracy (last character) (train :: test): 54.7% :: 65.5%
#
# iteration 96_000  time: 1892.1 seconds
# 	 	 loss(train :: test): 1.7502 :: 1.7267
# 	 	 accuracy (train :: test): 58.3% :: 57.9%
# 	 	 accuracy (last character) (train :: test): 66.4% :: 59.4%
#
# iteration 98_000  time: 1931.3 seconds
# 	 	 loss(train :: test): 1.7653 :: 1.7135
# 	 	 accuracy (train :: test): 56.3% :: 58.7%
# 	 	 accuracy (last character) (train :: test): 65.6% :: 60.4%
#
# iteration 99_999  time: 1970.5 seconds
# 	 	 loss(train :: test): 1.7617 :: 1.7219
# 	 	 accuracy (train :: test): 57.0% :: 58.4%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 61.4%

# %%
# plot the loss history
import matplotlib.pyplot as plt
plt.plot(time_history, loss_history, '-', label='train', color="blue")
plt.plot(time_test_history, loss_test_history, '-', label='test', lw=2, color="red")
plt.xlabel("Time (seconds)")
plt.ylabel("Loss")
plt.legend(loc='upper right')
plt.title("Training Loss History")
plt.grid()

# %%
B = 1
seed = 42
rng = jax.random.PRNGKey(seed)
prompt = "hello my fri"
# prompt_int = encode(prompt.lower())
prompt_int = jnp.array([ [char_to_int.get(c, len(char_set)) for c in prompt.lower()[:64]] ], dtype=jnp.int32)

gen_len = 1000
out_ids = generation.generate_tokens(model, params, rng, prompt_int, gen_len, block_size=64,
                          temperature=0.7, sample=True)
print('generated ids shape:', out_ids.shape)
print('generated text:')
generated_text = ''.join(int_to_char.get(int(x), '?') for x in list(out_ids[0]))
# concatenate with prompt
print(prompt + generated_text)
#print(''.join(int_to_char.get(int(x), '?') for x in list(out_ids[0])))
# Out:
# generated ids shape: (1, 1000)
# generated text:
# hello my fri il als ido ae aba sh aite on olinigaphan bes frpacccchoz ouccon rccale s willovisenese the ion ba p an fethe s ge ande leay kic wany gequd f chorimesicha an thanatarn aran uinarthalaly bazollt trio mo outhe f eto thre anired f dgep mimop caisthegrerecolethame ora wano pr ga s tconigridicousbe ollle ffoless onans enipe th ichiner ied b f thio thereralis is ef thollp pc twoatheef lanstes macal iched tocom waricathed ajon ave waushe wonaxin achy s ollor cingaridins ffft is oralltho onie we china thkiv chanefthe iathena andollllll t ga ge choverolaan ire olanan sl ss ginorid f pe avid c ya i preralil re istralid ach culalen eracetha ssstededaminchoucollllllirgly he wicathavic aly plirian ce c chevende in oriccin idethosto conchile s oten theny the ises d fffffforesstheranirend oustp dinarinenc wanganint me thameuran ddoure anthary o o on then lthounat wangismes c sthothaniroros p ouyanin th chal e war s wani anothete es misoabaraves fucoorbatworsthel cora ald dis thor h po wal dicaname ar
