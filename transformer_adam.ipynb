# %%
# Enable autoreload of local Python modules (e.g., models)
# %load_ext autoreload
# %autoreload 2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2460807974.py in <cell line: 0>()
#       1 # Enable autoreload of local Python modules (e.g., models)
# ----> 2 get_ipython().run_line_magic('load_ext', 'autoreload')
#       3 get_ipython().run_line_magic('autoreload', '2')
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# <decorator-gen-57> in load_ext(self, module_str)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/extension.py in load_ext(self, module_str)
#      31         if not module_str:
#      32             raise UsageError('Missing module name.')
# ---> 33         res = self.shell.extension_manager.load_extension(module_str)
#      34
#      35         if res == 'already loaded':
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/extensions.py in load_extension(self, module_str)
#      78             if module_str not in sys.modules:
#      79                 with prepended_to_syspath(self.ipython_extension_dir):
# ---> 80                     mod = import_module(module_str)
#      81                     if mod.__file__.startswith(self.ipython_extension_dir):
#      82                         print(("Loading extensions from {dir} is deprecated. "
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      88                 break
#      89             level += 1
# ---> 90     return _bootstrap._gcd_import(name[level:], package, level)
#      91
#      92
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.12/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/local/lib/python3.12/dist-packages/IPython/extensions/autoreload.py in <module>
#     119 from importlib import import_module
#     120 from importlib.util import source_from_cache
# --> 121 from imp import reload
#     122
#     123 #------------------------------------------------------------------------------
#
# ModuleNotFoundError: No module named 'imp'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import numpy as np
import jax
import jax.numpy as jnp
import optax
import time

# local imports
import models as models
import generation as generation

# %%
# initialize the jax random key
key = jax.random.key(0)

# %% [markdown]
# # Load data

# %%
# load the ./data/text8_train.txt and ./data/text8_test.txt files
with open("./text8_train.txt", "r") as f:
    train_text = f.read()
with open("./text8_test.txt", "r") as f:
    test_text = f.read()

# print the length of the training text and test text
print(f"Length of training text: {len(train_text):_} characters")
print(f"Length of test text: {len(test_text):_} characters")
# Out:
# Length of training text: 90_000_000 characters
# Length of test text: 5_000_000 characters

# %%
# Build vocabulary (lowercase + space + a few punctuations)
char_set = list("abcdefghijklmnopqrstuvwxyz ")
char_to_int = {ch:i for i,ch in enumerate(char_set)}
int_to_char = {i:ch for ch,i in char_to_int.items()}

def encode(s):
    """Encode string to array of integers"""
    ids = [char_to_int[c] for c in s]
    return np.array(ids, dtype=np.uint8)  # use np.uint8 to save space

# %%
# encode the text
train_text_int = encode(train_text)
test_text_int = encode(test_text)

# %%
# sanity check: display a few random characters from the training text
T = 128
for _ in range(5):
    # choose random position in text
    N = np.random.randint(low=0, high=len(train_text)-T)
    print(train_text[N:N+T])
    print()
# Out:
# of paran or the pomeranian pommersch dialect spoken in many different parts of southern brazil in the states of rio grande do su
#
#  game has also been spoofed by the onion in an issue which showed in six steps how kevin bacon is linked to al qaeda also it was
#
# g tension differs so much between solo and orchestral tuning that a different set of strings is required therefore the strings a
#
#  four book our knowledge of the external world as a field for scientific method in philosophy among the several schools that wer
#
# ve the book was reportedly written in the early one nine eight zero s but didn t receive the uk government s approval for public

# %% [markdown]
# # Create a basic Transformer model

# %%
def create_train_state(rng, vocab_size=27, d_model=64, n_layers=6, n_heads=8, max_len=128):
    # create a basic Transformer model
    model = models.DecoderOnlyTransformer(vocab_size, d_model, n_layers, n_heads, max_len)
    # create a dummy input for initialization
    dummy = jnp.zeros((1, min(16, max_len)), dtype=jnp.int32)
    # pass the dummy input to the model to initialize the parameters
    params = model.init({"params": rng}, dummy)["params"]
    return model, params

# %%
# vocab size
vocab_size= len(char_set)

# internal model dimensions
d_model=256

# number of attention heads
n_heads=8

# number of Transformer layers
n_layers=2

# maximum sequence length
max_len=128

model, params = create_train_state(key, vocab_size, d_model, n_layers, n_heads, max_len)

# %%
# compute the number of parameters
def count_params(params):
    return sum(x.size for x in jax.tree_util.tree_leaves(params))
print(f"Number of parameters: {count_params(params):_}")
# Out:
# Number of parameters: 1_624_576

# %%
# sanity check: create a batch of data & run a forward pass
B, T = 4, 32
batch = jax.random.randint(
    key=key,
    shape=(B, T), minval=0, maxval=len(char_set))
logits = model.apply({"params": params}, batch)

print("batch shape:", batch.shape)  # (B, T)
print("logits shape:", logits.shape)  # (B, T, vocab_size)
# Out:
# batch shape: (4, 32)
# logits shape: (4, 32, 27)

# %% [markdown]
# # Loss function

# %%
@jax.jit
def loss_and_metrics(logits, targets):
    """Compute cross-entropy loss and accuracy.

    Assumes `targets` contains only valid integer class ids in [0, V-1] (no -1 ignore tokens).

    Args:
      logits: (B, T, V) float array of unnormalized scores.
      targets: (B, T) integer array with ground-truth class ids.

    Returns:
      loss: scalar average cross-entropy over all positions.
      metrics: dict with keys "loss" and "acc" (both scalars).
    """
    # Flatten batch/time dims so optax works on shape (N, V) and (N,)
    vocab = logits.shape[-1]
    flat_logits = logits.reshape(-1, vocab)
    flat_targets = targets.reshape(-1)

    # Per-position cross-entropy, then mean over all positions
    per_pos = optax.softmax_cross_entropy_with_integer_labels(flat_logits, flat_targets)
    loss = per_pos.mean()

    # prediction over all positions
    preds = jnp.argmax(logits, axis=-1)  # (B, T)

    # compute accuracy over only the last position
    is_match = preds == targets

    # Accuracy over all positions
    acc_all = jnp.mean(is_match.astype(jnp.float32))

    # Accuracy over only last position
    acc_last = jnp.mean(is_match.astype(jnp.float32)[:,-1])

    return loss, {"loss": loss, "acc": acc_all, "acc_last": acc_last}

# %% [markdown]
# # Optimization step:

# %%
# create an update function
def train_step(params, opt_state, x, y, tx):
    """Single optimization step using optax optimizer.

    Args:
      params: pytree of model parameters.
      opt_state: optax optimizer state corresponding to `params`.
      x: (B, T) int array input tokens.
      y: (B, T) int array target tokens.
      tx: optax.GradientTransformation (already initialized).

    Returns:
      new_params: updated parameters after one gradient step.
      new_opt_state: updated optimizer state.
      metrics: dict of scalar metrics (loss, acc).
    """
    def loss_fn(params):
        logits = model.apply({"params": params}, x)
        loss, metrics = loss_and_metrics(logits, y)
        return loss, metrics

    # compute gradients (loss is scalar, metrics is auxiliary)
    (loss, metrics), grads = jax.value_and_grad(loss_fn, has_aux=True)(params)

    # optax update: compute parameter updates and new optimizer state
    updates, new_opt_state = tx.update(grads, opt_state, params)
    new_params = optax.apply_updates(params, updates)
    return new_params, new_opt_state, metrics

# jit: last argument should be static because it is an object
train_step = jax.jit(train_step, static_argnames=("tx",))

# %% [markdown]
# # Batch creation:

# %%
# create a batch from the training data
def get_batch(text_int, B, T):
    """Create a random batch of data from text_int.

    Args:
      text_int: 1D array of token ids.
      B: batch size (number of sequences).
      T: sequence length (number of tokens per sequence).

    Returns:
      x: (B, T) int array input tokens.
      y: (B, T) int array target tokens.
    """
    # choose random starting indices for each sequence in the batch
    ix = np.random.randint(0, len(text_int) - T, size=B)
    # inputs are text from i to i+T
    x = np.stack([text_int[i:i+T] for i in ix])
    # targets are text from i+1 to i+T+1
    y = np.stack([text_int[i+1:i+T+1] for i in ix])
    return jnp.array(x, dtype=jnp.int32), jnp.array(y, dtype=jnp.int32)

# %% [markdown]
# # Optimizer creation:

# %%
# define optax optimizer
learning_rate = 0.001
# Create Adam optimizer (Optax)
tx = optax.adam(learning_rate=learning_rate,
    b1=0.9,
    b2=0.98,
    eps=1e-9)
# Initialize optimizer state for current params
opt_state = tx.init(params)
print(f"Initialized optimizer: Adam lr={learning_rate}")
# Out:
# Initialized optimizer: Adam lr=0.001

# %%
niter = 100_000
B, T = 128, 32
loss_history = []
time_history = []
time_test_history = []
loss_test_history = []
time_start = time.time()
for it in range(niter):
    batch = get_batch(train_text_int, B, T)
    input, target = batch[0], batch[1]
    params_new, opt_state_new, metrics = train_step(params, opt_state, input, target, tx)

    # update params and opt_state
    params = params_new
    opt_state = opt_state_new
    acc = metrics['acc']
    acc_last = metrics['acc_last']
    loss = metrics['loss']

    loss_history.append(loss)
    time_history.append(time.time() - time_start)

    if it % (niter // 50) == 0 or it == niter - 1:
        time_since_start = time.time() - time_start
        # compute loss on test set
        B_test, T_test = 1024, 32
        test_batch = get_batch(test_text_int, B_test, T_test)
        test_input, test_target = test_batch[0], test_batch[1]
        test_logits = model.apply({"params": params}, test_input)
        test_loss, test_metrics = loss_and_metrics(test_logits, test_target)
        test_acc = test_metrics['acc']
        test_acc_last = test_metrics['acc_last']
        loss_test_history.append(test_loss)
        time_test_history.append(time_since_start)
        print(f"iteration {it:_}  time: {time_since_start:.1f} seconds")
        print(f"\t \t loss(train :: test): {loss:.4f} :: {test_loss:.4f}")
        print(f"\t \t accuracy (train :: test): {100*acc:.1f}% :: {100*test_acc:.1f}%")
        print(f"\t \t accuracy (last character) (train :: test): {100*acc_last:.1f}% :: {100*test_acc_last:.1f}%")
        print()
# Out:
# iteration 0  time: 6.0 seconds
# 	 	 loss(train :: test): 3.9478 :: 3.5324
# 	 	 accuracy (train :: test): 1.9% :: 17.4%
# 	 	 accuracy (last character) (train :: test): 3.1% :: 18.5%
#
# iteration 2_000  time: 41.9 seconds
# 	 	 loss(train :: test): 1.4995 :: 1.4990
# 	 	 accuracy (train :: test): 53.5% :: 53.4%
# 	 	 accuracy (last character) (train :: test): 52.3% :: 55.8%
#
# iteration 4_000  time: 74.9 seconds
# 	 	 loss(train :: test): 1.4753 :: 1.4412
# 	 	 accuracy (train :: test): 53.6% :: 55.2%
# 	 	 accuracy (last character) (train :: test): 53.9% :: 56.3%
#
# iteration 6_000  time: 110.4 seconds
# 	 	 loss(train :: test): 1.3959 :: 1.4023
# 	 	 accuracy (train :: test): 55.7% :: 56.1%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 57.0%
#
# iteration 8_000  time: 144.5 seconds
# 	 	 loss(train :: test): 1.4380 :: 1.3948
# 	 	 accuracy (train :: test): 54.9% :: 56.3%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 59.9%
#
# iteration 10_000  time: 179.1 seconds
# 	 	 loss(train :: test): 1.3585 :: 1.3701
# 	 	 accuracy (train :: test): 56.6% :: 57.1%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 58.7%
#
# iteration 12_000  time: 213.8 seconds
# 	 	 loss(train :: test): 1.3235 :: 1.3675
# 	 	 accuracy (train :: test): 58.2% :: 56.9%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 61.1%
#
# iteration 14_000  time: 248.2 seconds
# 	 	 loss(train :: test): 1.3580 :: 1.3749
# 	 	 accuracy (train :: test): 57.8% :: 57.0%
# 	 	 accuracy (last character) (train :: test): 70.3% :: 57.3%
#
# iteration 16_000  time: 283.0 seconds
# 	 	 loss(train :: test): 1.3451 :: 1.3641
# 	 	 accuracy (train :: test): 57.6% :: 57.2%
# 	 	 accuracy (last character) (train :: test): 64.1% :: 60.3%
#
# iteration 18_000  time: 317.7 seconds
# 	 	 loss(train :: test): 1.3056 :: 1.3454
# 	 	 accuracy (train :: test): 58.9% :: 57.9%
# 	 	 accuracy (last character) (train :: test): 65.6% :: 59.2%
#
# iteration 20_000  time: 352.3 seconds
# 	 	 loss(train :: test): 1.3553 :: 1.3673
# 	 	 accuracy (train :: test): 57.5% :: 57.3%
# 	 	 accuracy (last character) (train :: test): 54.7% :: 58.3%
#
# iteration 22_000  time: 386.8 seconds
# 	 	 loss(train :: test): 1.3394 :: 1.3363
# 	 	 accuracy (train :: test): 58.1% :: 57.9%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 61.1%
#
# iteration 24_000  time: 421.3 seconds
# 	 	 loss(train :: test): 1.3067 :: 1.3326
# 	 	 accuracy (train :: test): 58.6% :: 58.0%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 60.6%
#
# iteration 26_000  time: 455.8 seconds
# 	 	 loss(train :: test): 1.3266 :: 1.3569
# 	 	 accuracy (train :: test): 58.2% :: 57.4%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 59.4%
#
# iteration 28_000  time: 490.1 seconds
# 	 	 loss(train :: test): 1.2861 :: 1.3319
# 	 	 accuracy (train :: test): 59.4% :: 58.3%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 60.9%
#
# iteration 30_000  time: 524.5 seconds
# 	 	 loss(train :: test): 1.3258 :: 1.3544
# 	 	 accuracy (train :: test): 58.3% :: 57.7%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 61.7%
#
# iteration 32_000  time: 558.8 seconds
# 	 	 loss(train :: test): 1.3238 :: 1.3222
# 	 	 accuracy (train :: test): 58.5% :: 58.4%
# 	 	 accuracy (last character) (train :: test): 68.0% :: 60.4%
#
# iteration 34_000  time: 593.2 seconds
# 	 	 loss(train :: test): 1.2749 :: 1.3232
# 	 	 accuracy (train :: test): 59.7% :: 58.3%
# 	 	 accuracy (last character) (train :: test): 66.4% :: 59.4%
#
# iteration 36_000  time: 627.5 seconds
# 	 	 loss(train :: test): 1.3772 :: 1.3055
# 	 	 accuracy (train :: test): 57.0% :: 59.1%
# 	 	 accuracy (last character) (train :: test): 54.7% :: 62.6%
#
# iteration 38_000  time: 661.8 seconds
# 	 	 loss(train :: test): 1.2996 :: 1.3244
# 	 	 accuracy (train :: test): 58.7% :: 58.4%
# 	 	 accuracy (last character) (train :: test): 64.8% :: 60.0%
#
# iteration 40_000  time: 696.1 seconds
# 	 	 loss(train :: test): 1.2838 :: 1.3233
# 	 	 accuracy (train :: test): 59.3% :: 58.3%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 59.2%
#
# iteration 42_000  time: 730.4 seconds
# 	 	 loss(train :: test): 1.2861 :: 1.3144
# 	 	 accuracy (train :: test): 59.9% :: 58.8%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 62.9%
#
# iteration 44_000  time: 764.6 seconds
# 	 	 loss(train :: test): 1.3169 :: 1.3030
# 	 	 accuracy (train :: test): 58.3% :: 58.9%
# 	 	 accuracy (last character) (train :: test): 66.4% :: 61.3%
#
# iteration 46_000  time: 798.8 seconds
# 	 	 loss(train :: test): 1.2748 :: 1.3045
# 	 	 accuracy (train :: test): 59.2% :: 58.8%
# 	 	 accuracy (last character) (train :: test): 64.8% :: 64.1%
#
# iteration 48_000  time: 833.0 seconds
# 	 	 loss(train :: test): 1.2498 :: 1.3188
# 	 	 accuracy (train :: test): 60.6% :: 58.6%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 59.9%
#
# iteration 50_000  time: 867.4 seconds
# 	 	 loss(train :: test): 1.3004 :: 1.3209
# 	 	 accuracy (train :: test): 58.6% :: 58.5%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 62.1%
#
# iteration 52_000  time: 902.4 seconds
# 	 	 loss(train :: test): 1.3103 :: 1.3190
# 	 	 accuracy (train :: test): 58.4% :: 58.7%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 64.8%
#
# iteration 54_000  time: 936.8 seconds
# 	 	 loss(train :: test): 1.2462 :: 1.3184
# 	 	 accuracy (train :: test): 60.0% :: 58.6%
# 	 	 accuracy (last character) (train :: test): 70.3% :: 62.7%
#
# iteration 56_000  time: 971.2 seconds
# 	 	 loss(train :: test): 1.2960 :: 1.2936
# 	 	 accuracy (train :: test): 59.2% :: 59.3%
# 	 	 accuracy (last character) (train :: test): 53.1% :: 61.2%
#
# iteration 58_000  time: 1005.6 seconds
# 	 	 loss(train :: test): 1.2621 :: 1.2971
# 	 	 accuracy (train :: test): 59.8% :: 58.9%
# 	 	 accuracy (last character) (train :: test): 64.8% :: 59.4%
#
# iteration 60_000  time: 1040.1 seconds
# 	 	 loss(train :: test): 1.2577 :: 1.3119
# 	 	 accuracy (train :: test): 60.7% :: 58.9%
# 	 	 accuracy (last character) (train :: test): 72.7% :: 61.9%
#
# iteration 62_000  time: 1074.5 seconds
# 	 	 loss(train :: test): 1.3128 :: 1.2998
# 	 	 accuracy (train :: test): 59.4% :: 59.2%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 62.5%
#
# iteration 64_000  time: 1108.9 seconds
# 	 	 loss(train :: test): 1.2935 :: 1.2949
# 	 	 accuracy (train :: test): 59.2% :: 59.3%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 62.9%
#
# iteration 66_000  time: 1143.2 seconds
# 	 	 loss(train :: test): 1.2741 :: 1.3014
# 	 	 accuracy (train :: test): 60.2% :: 59.2%
# 	 	 accuracy (last character) (train :: test): 69.5% :: 61.6%
#
# iteration 68_000  time: 1177.4 seconds
# 	 	 loss(train :: test): 1.2864 :: 1.3107
# 	 	 accuracy (train :: test): 59.8% :: 58.8%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 59.6%
#
# iteration 70_000  time: 1211.8 seconds
# 	 	 loss(train :: test): 1.3282 :: 1.2939
# 	 	 accuracy (train :: test): 58.1% :: 59.3%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 62.7%
#
# iteration 72_000  time: 1246.4 seconds
# 	 	 loss(train :: test): 1.2274 :: 1.2941
# 	 	 accuracy (train :: test): 61.0% :: 59.2%
# 	 	 accuracy (last character) (train :: test): 66.4% :: 63.3%
#
# iteration 74_000  time: 1280.9 seconds
# 	 	 loss(train :: test): 1.2590 :: 1.3229
# 	 	 accuracy (train :: test): 59.5% :: 58.2%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 62.7%
#
# iteration 76_000  time: 1315.5 seconds
# 	 	 loss(train :: test): 1.2712 :: 1.3009
# 	 	 accuracy (train :: test): 60.2% :: 59.4%
# 	 	 accuracy (last character) (train :: test): 66.4% :: 64.9%
#
# iteration 78_000  time: 1350.1 seconds
# 	 	 loss(train :: test): 1.2614 :: 1.2914
# 	 	 accuracy (train :: test): 60.0% :: 59.5%
# 	 	 accuracy (last character) (train :: test): 63.3% :: 61.4%
#
# iteration 80_000  time: 1384.8 seconds
# 	 	 loss(train :: test): 1.2699 :: 1.3150
# 	 	 accuracy (train :: test): 60.5% :: 58.7%
# 	 	 accuracy (last character) (train :: test): 66.4% :: 64.6%
#
# iteration 82_000  time: 1419.3 seconds
# 	 	 loss(train :: test): 1.3065 :: 1.3043
# 	 	 accuracy (train :: test): 58.9% :: 58.7%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 62.0%
#
# iteration 84_000  time: 1453.8 seconds
# 	 	 loss(train :: test): 1.2191 :: 1.3054
# 	 	 accuracy (train :: test): 61.5% :: 59.4%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 62.2%
#
# iteration 86_000  time: 1488.3 seconds
# 	 	 loss(train :: test): 1.2775 :: 1.2885
# 	 	 accuracy (train :: test): 59.1% :: 59.3%
# 	 	 accuracy (last character) (train :: test): 67.2% :: 64.0%
#
# iteration 88_000  time: 1522.7 seconds
# 	 	 loss(train :: test): 1.3342 :: 1.2812
# 	 	 accuracy (train :: test): 58.5% :: 59.9%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 63.1%
#
# iteration 90_000  time: 1557.2 seconds
# 	 	 loss(train :: test): 1.2724 :: 1.2793
# 	 	 accuracy (train :: test): 60.0% :: 59.6%
# 	 	 accuracy (last character) (train :: test): 66.4% :: 64.7%
#
# iteration 92_000  time: 1591.6 seconds
# 	 	 loss(train :: test): 1.2477 :: 1.2902
# 	 	 accuracy (train :: test): 60.7% :: 59.4%
# 	 	 accuracy (last character) (train :: test): 64.8% :: 60.7%
#
# iteration 94_000  time: 1626.0 seconds
# 	 	 loss(train :: test): 1.2407 :: 1.2738
# 	 	 accuracy (train :: test): 60.1% :: 59.9%
# 	 	 accuracy (last character) (train :: test): 63.3% :: 62.1%
#
# iteration 96_000  time: 1660.4 seconds
# 	 	 loss(train :: test): 1.2815 :: 1.2925
# 	 	 accuracy (train :: test): 59.3% :: 59.6%
# 	 	 accuracy (last character) (train :: test): 69.5% :: 62.0%
#
# iteration 98_000  time: 1694.9 seconds
# 	 	 loss(train :: test): 1.2611 :: 1.3037
# 	 	 accuracy (train :: test): 60.7% :: 59.1%
# 	 	 accuracy (last character) (train :: test): 70.3% :: 64.2%
#
# iteration 99_999  time: 1729.3 seconds
# 	 	 loss(train :: test): 1.2559 :: 1.2844
# 	 	 accuracy (train :: test): 60.4% :: 60.0%
# 	 	 accuracy (last character) (train :: test): 67.2% :: 63.6%

# %%
# plot the loss history
import matplotlib.pyplot as plt
plt.plot(time_history, loss_history, '-', label='train', color="blue")
plt.plot(time_test_history, loss_test_history, '-', label='test', lw=2, color="red")
plt.xlabel("Time (seconds)")
plt.ylabel("Loss")
plt.legend(loc='upper right')
plt.title("Training Loss History")
plt.grid()

# %%
B = 1
seed = 42
rng = jax.random.PRNGKey(seed)
prompt = "hello my fri"
# prompt_int = encode(prompt.lower())
prompt_int = jnp.array([ [char_to_int.get(c, len(char_set)) for c in prompt.lower()[:64]] ], dtype=jnp.int32)

gen_len = 1000
out_ids = generation.generate_tokens(model, params, rng, prompt_int, gen_len, block_size=64,
                          temperature=0.7, sample=True)
print('generated ids shape:', out_ids.shape)
print('generated text:')
generated_text = ''.join(int_to_char.get(int(x), '?') for x in list(out_ids[0]))
# concatenate with prompt
print(prompt + generated_text)
#print(''.join(int_to_char.get(int(x), '?') for x in list(out_ids[0])))
# Out:
# generated ids shape: (1, 1000)
# generated text:
# hello my fridie an idoidae a h sh a t atorolininarynderes llines chou ouckalo c a ch d me ov uxidelinev iokiamimacimon tw segite drica a stonanan ganadr wn orimarich foc k alidagelis a u cathbll dstbinnofestis ong irellef es la resp t ponid teprelelea is evelanascolet ama opalint hedon os tcande s ilochert mal coud p sinalime haritrates ber se pin f t blinoves bes a fred thrlararelalat ches lis oanedewil inindinoxea w s ast edeamo fongawen hes bicelindety st panedaineaneriglarot liamarat t oporall wa he sty kalochanith s is ides an ched be t gian a piela t al imacoraner risonulestret f panarined ylly pres lilidonial reterama blarongu fededdis t id aratincherer laly italt hede tol are s es pinashe c ale ttt t fanex plimimarothandon s thanit s ora by f he alia hes canarinalesix pr alo carestedodote wis c we ates timonales op ph doures on ary hnopones s mamus att thedin inorinomure arimans pananarorat hovis malia s wini acotis fin iolelo firccoux mas macenonacalelaca an oled ts a ha oridalideria atis
